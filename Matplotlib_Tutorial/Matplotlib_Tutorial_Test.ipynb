# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Making Plots Actually Look Nice
#
# If one has SciencePlots (https://github.com/garrettj403/SciencePlots) installed has additional options for matplotlib

# %%
print(plt.style.available)
plt.style.use(['fivethirtyeight'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# # Quick Plotting

# %% [markdown]
# ## Line Plots

# %% [markdown]
# Simple plotting commands to look at data quickly

# %%
x = np.linspace(0, 15, 30)
y = np.sin(x) + 0.1 * np.random.randn(len(x))

# %%
plt.plot(x,y, "o--")

# %%
plt.plot(x, y, "o--", color="purple", lw=2, ms=10)

# %% [markdown]
# Figure size

# %%
plt.figure(figsize=(8, 4))
plt.rc("xtick", labelsize=20)
plt.rc("ytick", labelsize=20)
plt.plot(x, y)
plt.title("ABC")
# Out:
# Text(0.5, 1.0, 'ABC')

# %% [markdown]
# Axis labels

# %%
plt.figure(figsize=(8, 3))
plt.rc("xtick", labelsize=15)
plt.rc("ytick", labelsize=15)
plt.rc("legend", fontsize=15)
plt.plot(x, y, "o--", label="Component 1")
plt.xlabel("Time [s]", fontsize=16)
plt.ylabel("Voltage [V]")
plt.title("Voltage in 3rd Electrode")
plt.legend()
plt.show()

# %% [markdown]
# Legend

# %%
plt.figure(figsize=(8,3))
plt.plot(x,y, label='Component 1')
plt.xlabel('Time [s]', fontsize=16)
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc='lower right', fontsize=18)
plt.show()

# %% [markdown]
# Easy to have multiple lines on same plot

# %%
x2 = np.linspace(0, 15, 100)
y2 = np.sin(x2)

# %%
plt.figure(figsize=(8, 3))
plt.plot(x, y, "o", label="Data", zorder=10, ms=10)
plt.plot(x2, y2, "-", label="Fit")
plt.xlabel("Time [s]", fontsize=16)
plt.ylabel("Voltage [V]")
plt.title("Voltage in 3rd Electrode")
plt.legend(loc="lower right", fontsize=12)
plt.show()

# %% [markdown]
# $x$ and $y$ limits

# %%
plt.figure(figsize=(8, 3))
plt.plot(x, y, "o", label="Data", zorder=10, ms=10)
plt.plot(x2, y2, "-", label="Fit")
plt.xlabel("Time [s]", fontsize=16)
plt.ylabel("Voltage [V]")
plt.title("Voltage in 3rd Electrode")
plt.legend(loc="lower right", fontsize=12)
plt.ylim((-2, 2))
plt.xlim((-1, 16))
plt.show()

# %% [markdown]
# ## Histograms

# %%
res = np.random.randn(1000) * 0.2 + 1

# %% [markdown]
# Quick Histogram

# %%
plt.figure(figsize=(8, 3))
plt.hist(res, bins=50)
plt.show()

# %% [markdown]
# Change number of bins

# %%
plt.figure(figsize=(8,3))
plt.hist(res, bins=100)
plt.show()

# %% [markdown]
# Convert to density plot

# %%
plt.figure(figsize=(8,3))
plt.hist(res, bins=100, density=True)
plt.show()

# %% [markdown]
# Differnt style of bins (useful for plotting multiple histograms)

# %%
res2 = np.random.randn(1000) * 0.2 + 0.4

# %%
plt.figure(figsize=(8, 3))
plt.hist(res, bins=30, density=True, histtype="barstacked")
plt.hist(res2, bins=30, density=True, histtype="barstacked")
plt.xlabel("$\hat{E}-E$", fontsize=20)
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # A More Advanced API
#
# For more complicated plots, such as
#
# * Multiple subplots on 1 figure
# * Conveniently adding text to plots
# * Creating animations
#
# one needs to use a slightly more advanced API

# %% [markdown]
# ## Single Axes in one Figure

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 4))
ax.plot(x, y, "o--", color="r", lw=1, ms=3)
ax.text(0.1, 0.1, "text here", transform=ax.transAxes)
ax.set_xlabel("Time [s]")
ax.set_ylabel(r"$\frac{d}{dx} f(x)$", fontsize=15, rotation="horizontal")
plt.show()

# %% [markdown]
# ## Multiple axes in 1 figure

# %%
fig, axes = plt.subplots(3, 2, figsize=(8, 8))
ax = axes[0][0]
ax.plot(x, y, "o--", color="r", lw=0.4, ms=3)
ax.text(0.1, 0.1, "text here", transform=ax.transAxes)
ax = axes[1][1]
ax.hist(res, bins=30, density=True, histtype="bar", label="C1")
ax.hist(res2, bins=30, density=True, histtype="bar", label="C1")
ax.set_xlabel("$\hat{E}-E$")
ax.legend()
fig.tight_layout()
fig.suptitle("Title of All Plots", y=1.03, fontsize=25)
plt.show()

# %% [markdown]
# Can make x-ticks smaller

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 3))
ax.plot(x, y, "o--", color="r", lw=1, ms=5)
ax.text(0.1, 0.1, "text here", transform=ax.transAxes)
ax.set_xlabel("Time [s]")
ax.set_ylabel(r"$\frac{d}{dx} f(x)$", fontsize=15, rotation="horizontal")
ax.tick_params(axis="both", which="major", labelsize=10)
ax.grid("minor")
plt.show()

# %% [markdown]
# # Example
#
# Creating the following plot

# %%
res_a1 = 0.2 * np.random.randn(1000) + 0.4
res_b1 = 0.25 * np.random.randn(1000) + 0.4
res_a2 = 0.21 * np.random.randn(1000) + 0.3
res_b2 = 0.22 * np.random.randn(1000) + 0.3

# %% [markdown]
# Good habit to come up with complicated strings beforehand

# %%
textstr1 = "\n".join(
    (r"$\sigma_a=%.4f$" % (np.std(res_a1)), r"$\sigma_b=%.4f$" % (np.std(res_b1)))
)

textstr2 = "\n".join(
    (r"$\sigma_a=%.4f$" % (np.std(res_a2)), r"$\sigma_b=%.4f$" % (np.std(res_b2)))
)

# %% [markdown]
# Make plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3.5))
ax = axes[0]
ax.hist(res_a1, bins=30, density=True, histtype="step", label="Method a", color="blue")
ax.hist(res_b1, bins=30, density=True, histtype="step", label="Method b", color="red")
ax.text(
    0.05,
    0.81,
    textstr1,
    transform=ax.transAxes,
    bbox=dict(facecolor="white", edgecolor="black"),
    size=12,
)

ax.legend(fontsize=10, fancybox=False, edgecolor="black")
ax.set_ylabel("Frequency")
ax.set_title("Trial 1")
ax = axes[1]
ax.hist(res_a2, bins=30, density=True, histtype="step", label="Method 1", color="blue")
ax.hist(res_b2, bins=30, density=True, histtype="step", label="Method 2", color="red")
ax.text(
    0.05,
    0.81,
    textstr2,
    transform=ax.transAxes,
    bbox=dict(facecolor="white", edgecolor="black"),
    size=12,
)
ax.set_title("Trial 2")
fig.text(0.5, -0.04, "$\Delta E$ [Joules]", ha="center", size=20)
plt.savefig("trial.png", dpi=200)
plt.show()

# %% [markdown]
# # 2D Plots

# %% [markdown]
# Generate some data

# %%
# plt.style.available
plt.style.use("fivethirtyeight")

# %%
_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_, _)
z = x**2 + x * y

# %% [markdown]
# ## Filled-in contour plots

# %%
plt.contourf(x, y, z, cmap="inferno")

# %% [markdown]
# Can make them more dense ny changing `levels` and also can change colormap
#
# * See https://matplotlib.org/stable/tutorials/colors/colormaps.html#sphx-glr-tutorials-colors-colormaps-py
#
# Can use `vmin` and `vmax` to adjust the color range
#
# * See https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.contour.html for all settings

# %%
plt.contourf(x, y, z, levels=50, cmap="plasma")
plt.colorbar(label="Temperature [$^\circ C$]")
plt.xlabel("Horizontal Position [m]")
plt.ylabel("Vertical Position [m]")
# Out:
# Text(0, 0.5, 'Vertical Position [m]')

# %% [markdown]
# ## Contour Plot

# %% [markdown]
# Sometimes, the following is preferred:

# %%
plt.figure(figsize=(10, 8))
plt.rc("xtick", labelsize=20)
plt.rc("ytick", labelsize=20)
cs = plt.contour(x, y, z, levels=20, cmap="plasma")
plt.clabel(cs, fontsize=15)
# Out:
# <a list of 28 text.Text objects>

# %% [markdown]
# ## 3D Surface Plot

# %% [markdown]
# 3D Surface Plot (Generally not preferred). However, they tend to work well in animations (we'll get to this later)

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(x, y, z, cmap="coolwarm", linewidth=0, antialiased=False)
ax.view_init(elev=10, azim=-20)

# %% [markdown]
# ## StreamPlots

# %% [markdown]
# For plotting vector fields

# %%
w = 3
_ = np.linspace(-3,3,100)
X, Y = np.meshgrid(_,_)
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 8))
ax = axes[0][0]
ax.streamplot(X, Y, U, V)
ax = axes[0][1]
ax.streamplot(X, Y, U, V, color=speed)
ax = axes[1][0]
lw = 5 * speed / speed.max()
ax.streamplot(X, Y, U, V, linewidth=lw)
ax = axes[1][1]
seed_points = np.array([[0, 1], [1, 0]])
ax.streamplot(X, Y, U, V, color=U, linewidth=2, cmap="autumn", start_points=seed_points)
ax.grid()

# %% [markdown]
# # Image Reading

# %%
im = plt.imread('images/flower.png')

# %% [markdown]
# Plot image

# %%
plt.imshow(im)

# %% [markdown]
# # Animations

# %% [markdown]
# Animations require relating the time of your problem to the frame of the animation, then specifying the frames per second
#
# * Below is a $\sin$ wave moving at 3m/s. Translate this into an animation

# %%
def f(x,t):
    return np.sin(x-3*t)

x = np.linspace(0, 10*np.pi, 1000)
t = np.arange(0, 24, 1/60)
X, T = np.meshgrid(x, t)
F = f(X, T)

# %%
plt.plot(x, F[1])

# %% [markdown]
# Create animation

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

# %%
fig, ax = plt.subplots(1,1, figsize=(8,4))
ln1, = plt.plot([], [])
time_text = ax.text(0.65, 0.95, '', fontsize=15,
                    bbox=dict(facecolor='white', edgecolor='black'), 
                    transform=ax.transAxes)
ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5, 1.5)

def animate(i):
    ln1.set_data(x, F[i])
    time_text.set_text('t={:.2f}'.format(i/60))
    
ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
ani.save('images/ani.gif',writer='pillow',fps=50,dpi=100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[329], line 14
#      11     time_text.set_text('t={:.2f}'.format(i/60))
#      13 ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
# ---> 14 ani.save('images/ani.gif',writer='pillow',fps=50,dpi=100)
#
# File c:\Python\Python_3.10\lib\site-packages\matplotlib\animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1085 savefig_kwargs['transparent'] = False   # just to be safe!
#    1086 # canvas._is_saving = True makes the draw_event animation-starting
#    1087 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1088 # widget (both are likewise done in savefig()).
# -> 1089 with writer.saving(self._fig, filename, dpi), \
#    1090      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1091     for anim in all_anim:
#    1092         anim._init_draw()  # Clear the initial frame
#
# File c:\Python\Python_3.10\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File c:\Python\Python_3.10\lib\site-packages\matplotlib\animation.py:240, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     235     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#     236               "frame size to vary, which is inappropriate for "
#     237               "animation.")
#     239 # This particular sequence is what contextlib.contextmanager wants
# --> 240 self.setup(fig, outfile, dpi, *args, **kwargs)
#     241 with mpl.rc_context({'savefig.bbox': None}):
#     242     try:
#
# File c:\Python\Python_3.10\lib\site-packages\matplotlib\animation.py:503, in PillowWriter.setup(self, fig, outfile, dpi)
#     502 def setup(self, fig, outfile, dpi=None):
# --> 503     super().setup(fig, outfile, dpi=dpi)
#     504     self._frames = []
#
# File c:\Python\Python_3.10\lib\site-packages\matplotlib\animation.py:195, in AbstractMovieWriter.setup(self, fig, outfile, dpi)
#     181 """
#     182 Setup for writing the movie file.
#     183
#    (...)
#     192     in pixels of the resulting movie file.
#     193 """
#     194 # Check that path is valid
# --> 195 Path(outfile).parent.resolve(strict=True)
#     196 self.outfile = outfile
#     197 self.fig = fig
#
# File c:\Python\Python_3.10\lib\pathlib.py:1077, in Path.resolve(self, strict)
#    1074         raise RuntimeError("Symlink loop from %r" % e.filename)
#    1076 try:
# -> 1077     s = self._accessor.realpath(self, strict=strict)
#    1078 except OSError as e:
#    1079     check_eloop(e)
#
# File c:\Python\Python_3.10\lib\ntpath.py:689, in realpath(path, strict)
#     687     path = join(cwd, path)
#     688 try:
# --> 689     path = _getfinalpathname(path)
#     690     initial_winerror = 0
#     691 except OSError as ex:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'd:\\DATA SCIENCE\\GIT\\DS\\Matplotlib_Tutorial\\images'

# %% [markdown]
# The animation function can be used in other ways too. One can create 3D rotating gifs of surfaces.

# %%
_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_,_)
z = x**2+x*y

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(x,y,z, cmap='coolwarm',
                       linewidth=0, antialiased=False)
ax.view_init(elev=10, azim=0)

def animate(i):
    ax.view_init(elev=10, azim=3*i)
    
ani = animation.FuncAnimation(fig, animate, frames=120, interval=50)
ani.save('images/ani2.gif',writer='pillow',fps=30,dpi=100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[331], line 10
#       7     ax.view_init(elev=10, azim=3*i)
#       9 ani = animation.FuncAnimation(fig, animate, frames=120, interval=50)
# ---> 10 ani.save('images/ani2.gif',writer='pillow',fps=30,dpi=100)
#
# File c:\Python\Python_3.10\lib\site-packages\matplotlib\animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1085 savefig_kwargs['transparent'] = False   # just to be safe!
#    1086 # canvas._is_saving = True makes the draw_event animation-starting
#    1087 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1088 # widget (both are likewise done in savefig()).
# -> 1089 with writer.saving(self._fig, filename, dpi), \
#    1090      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1091     for anim in all_anim:
#    1092         anim._init_draw()  # Clear the initial frame
#
# File c:\Python\Python_3.10\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File c:\Python\Python_3.10\lib\site-packages\matplotlib\animation.py:240, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     235     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#     236               "frame size to vary, which is inappropriate for "
#     237               "animation.")
#     239 # This particular sequence is what contextlib.contextmanager wants
# --> 240 self.setup(fig, outfile, dpi, *args, **kwargs)
#     241 with mpl.rc_context({'savefig.bbox': None}):
#     242     try:
#
# File c:\Python\Python_3.10\lib\site-packages\matplotlib\animation.py:503, in PillowWriter.setup(self, fig, outfile, dpi)
#     502 def setup(self, fig, outfile, dpi=None):
# --> 503     super().setup(fig, outfile, dpi=dpi)
#     504     self._frames = []
#
# File c:\Python\Python_3.10\lib\site-packages\matplotlib\animation.py:195, in AbstractMovieWriter.setup(self, fig, outfile, dpi)
#     181 """
#     182 Setup for writing the movie file.
#     183
#    (...)
#     192     in pixels of the resulting movie file.
#     193 """
#     194 # Check that path is valid
# --> 195 Path(outfile).parent.resolve(strict=True)
#     196 self.outfile = outfile
#     197 self.fig = fig
#
# File c:\Python\Python_3.10\lib\pathlib.py:1077, in Path.resolve(self, strict)
#    1074         raise RuntimeError("Symlink loop from %r" % e.filename)
#    1076 try:
# -> 1077     s = self._accessor.realpath(self, strict=strict)
#    1078 except OSError as e:
#    1079     check_eloop(e)
#
# File c:\Python\Python_3.10\lib\ntpath.py:689, in realpath(path, strict)
#     687     path = join(cwd, path)
#     688 try:
# --> 689     path = _getfinalpathname(path)
#     690     initial_winerror = 0
#     691 except OSError as ex:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'd:\\DATA SCIENCE\\GIT\\DS\\Matplotlib_Tutorial\\images'
